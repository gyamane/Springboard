# %% [markdown]
# # Application of Inferential Statistics: Washington D.C. and King County Housing Sale Price Analysis

# %% [markdown]
# ## Data

# %%
# Import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.formula.api import ols

# %%
# Create df on Macbook
dc_df = pd.read_csv("/Users/garrettyamane/Desktop/Springboard/capstone_project_2/data/dc_updated.csv")
kc_df = pd.read_csv("/Users/garrettyamane/Desktop/Springboard/capstone_project_2/data/kc_updated.csv")

# Create df on PC
# dc_df = pd.read_csv("/Users/Garrett/Desktop/Springboard/capstone_project_2/data/dc_updated.csv")
# kc_df = pd.read_csv("/Users/Garrett/Desktop/Springboard/capstone_project_2/data/kc_updated.csv")

dc_df = dc_df.drop(columns='Unnamed: 0')
kc_df = kc_df.drop(columns='Unnamed: 0')

# Apply fixes to dataframes for outliers
dc_df.condition = dc_df[dc_df.condition != 'Missing'].condition

# %% [markdown]
# # Average Housing Price: Is there a statistical significance between the average housing sale price between Washington D.C. and King County?

# %% [markdown]
# Code referenced from http://onlinestatbook.com/mobile/tests_of_means/difference_means.html.
# I will compare the difference of means between the housing sale prices in Washington D.C and King County by testing the following hypotheses:
#
# ***H<sub>0</sub> :*** The true mean housing sale price between the Washington D.C. and King County are the same <br>
# ***H<sub>1</sub> :*** The true mean housing sale price between the Washington D.C. and King County are *not* the same <br>
# For each, I assume an $\alpha$ level of 0.05

# %% [markdown]
# ### Washington D.C. Housing Statistics

# %%
dc_df.price.describe().apply(lambda x: format(x, 'f'))
# Out:
# count       7160.000000
# mean      627126.845391
# std       510667.841622
# min         5185.000000
# 25%       345000.000000
# 50%       517000.000000
# 75%       749600.000000
# max      7395000.000000
# Name: price, dtype: object

# %% [markdown]
# ### King County Housing Statistics

# %%
kc_df.price.describe().apply(lambda x: format(x, 'f'))
# Out:
# count      21613.000000
# mean      540088.141767
# std       367127.196483
# min        75000.000000
# 25%       321950.000000
# 50%       450000.000000
# 75%       645000.000000
# max      7700000.000000
# Name: price, dtype: object

# %% [markdown]
# #### Compute the test statistic: Mean of the sampling distribution of the difference between means

# %%
test_stat = dc_df.price.mean() - kc_df.price.mean()
print("Mean difference of means for Washington D.C. and King County Housing Sales:", test_stat)
# Out:
# Mean difference of means for Washington D.C. and King County Housing Sales: 87038.70362453209

# %% [markdown]
# In order to test for the difference of means between the Washington D.C. and King County housing prices data sets, there are 3 assumptions that I am going to make:
#
# 1. The Washington D.C. and King County housing data sets have the same variance
# 2. Each housing price population is normally distributed
# 3. Each housing price is sampled independently from each other value. This assumption means that each housing unit sold is for one value only

# %% [markdown]
# #### Calculate the Standard Error of the test statistic

# %% [markdown]
# The formula for the variance of the sampling distribution of the mean is: ![image.png](attachment:image.png)
# where σ is the standard deviation and N is the sample size.

# %% [markdown]
# Because the Washington D.C. and King County are different populations and have different sample sizes, we need to disinguish between them via subscripts to represent each population: ![image.png](attachment:image.png)

# %% [markdown]
# Using the above formulas, I can use ![image.png](attachment:image.png)
# to calculate the standard error of the difference of means between the two populations.

# %% [markdown]
# #### Calculate the standard error of the test statistic

# %%
# Calculate standard error of test statistic
dc_var = dc_df.price.var()
kc_var = kc_df.price.var()
dc_size = len(dc_df.price)
kc_size = len(kc_df.price)

standard_err = np.sqrt((dc_var / dc_size) + (kc_var / kc_size))

# %% [markdown]
# #### Compute the t-statistic and get p-value

# %% [markdown]
# Now that I have the standard error, I can plug it into ![image.png](attachment:image.png)
# to get the t-statistic and use this to get the probability (p-value) of getting a t as large or larger than the t-statistic or as small or smaller than -(t-statistic).

# %%
# Compute t-statistic
t_stat = test_stat / standard_err

# Degrees of freedom
dof = dc_size + kc_size - 2

# Compute p-value
p_val = 1 - stats.t.cdf(t_stat,df=dof)

print("p-value:", p_val)
# Out:
# p-value: 0.0

# %% [markdown]
# Since the p-value is less than 0.05, I can confidently reject my null hypothesis that the true mean housing sale prices in Washington D.C. and King County are the same.

# %% [markdown]
# # Linear Relationships Between Non-categorical Housing Features and Housing Prices
# By examining a linear regression model for each individual non-categorical housing features with the housing sale price, I can determine which features are statistically significant predictors of housing sale prices.

# %% [markdown]
# #### All housing features

# %%
dc_df.columns
# Out:
# Index(['price', 'date', 'bathrooms', 'bedrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'condition', 'grade', 'yr_built', 'yr_renovated', 'location'],
#       dtype='object')

# %%
def generate_plot(df, location, column, pvalue_dict):
    """Code referenced from https://stackoverflow.com/questions/45902739/seaborn-annotate-the-linear-regression-equation"""    
    
    # get coeffs of linear fit
    slope, intercept, r_value, p_value, std_err = stats.linregress(df[column] , df["price"])

    # use line_kws to set line label for legend
    ax = sns.regplot(x=column, y="price", data=df, color='b', 
     line_kws={'label':"y={0:.1f}x+{1:.1f}".format(slope,intercept)})
    
    ax.set_title(location + ": " + column + " vs. price Regression Plot", fontsize=20)
    plt.xlabel(column, fontsize=15)
    plt.ylabel('price', fontsize=15)
    pvalue_dict[column] = p_value

# %%
dc_pvals = {}
kc_pvals = {}

dc_pearsons = {}
kc_pearsons = {}
columns = ["bathrooms", "bedrooms", "sqft_living", "sqft_lot", "floors", "yr_built", "yr_renovated"]

# %%
for c in columns:
    # Plot pie chart
    fig = plt.figure(figsize=(20, 8))

    # Pie chart for D.C. Condition
    ax = fig.add_subplot(1, 2, 1)
    generate_plot(dc_df, "Washington D.C.", c, dc_pvals)

    # Pie chart for King County Condition
    ax = fig.add_subplot(1, 2, 2)
    generate_plot(kc_df, "King County", c, kc_pvals)

# %%
pvals_df = pd.DataFrame(dc_pvals, index=["D.C."])
pvals_df = pvals_df.append(pd.DataFrame(kc_pvals, index=["KC"]))

# %% [markdown]
# #### P-values for each non-categorical variable

# %%
pvals_df
# Out:
#       bathrooms  bedrooms  sqft_living       sqft_lot         floors  \
# D.C.        0.0       0.0          0.0  7.746301e-283  2.768112e-166
# KC          0.0       0.0          0.0   7.972505e-40   0.000000e+00
#
#           yr_built  yr_renovated
# D.C.  1.935821e-07  3.570190e-04
# KC    1.929873e-15  1.021348e-77

# %% [markdown]
# Because the p-value for each non-categorical variable in both the Washington D.C. data set and King County data set is less than the alpha value of 0.05, each variable would be a good predictor for price.

# %% [markdown]
# # Linear Regression Models for Categorical Features on Price

# %% [markdown]
# ## Washington D.C. Categorical Features

# %%
# Create month column for each data frame
dc_df['month'] = pd.to_datetime(dc_df['date']).dt.month
kc_df['month'] = pd.to_datetime(kc_df['date']).dt.month

category_cols = ['month', 'grade', 'condition']

# %% [markdown]
# #### Washington D.C. - Month

# %%
m = ols('price ~ C(month)',dc_df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.457
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):            0.00461
# Time:                        22:07:45   Log-Likelihood:            -1.0425e+05
# No. Observations:                7160   AIC:                         2.085e+05
# Df Residuals:                    7148   BIC:                         2.086e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       6.422e+05    2.6e+04     24.702      0.000    5.91e+05    6.93e+05
# C(month)[T.2]  -1.741e+04   3.71e+04     -0.469      0.639   -9.02e+04    5.53e+04
# C(month)[T.3]  -4.629e+04   3.45e+04     -1.341      0.180   -1.14e+05    2.14e+04
# C(month)[T.4]  -3.318e+04   3.29e+04     -1.009      0.313   -9.76e+04    3.13e+04
# C(month)[T.5]   1.891e+04   2.98e+04      0.634      0.526   -3.95e+04    7.74e+04
# C(month)[T.6]   3.836e+04   3.26e+04      1.175      0.240   -2.56e+04    1.02e+05
# C(month)[T.7]    1.05e+04   3.26e+04      0.322      0.747   -5.33e+04    7.43e+04
# C(month)[T.8]   -1.61e+04    3.4e+04     -0.473      0.636   -8.28e+04    5.06e+04
# C(month)[T.9]  -5.148e+04   3.46e+04     -1.486      0.137   -1.19e+05    1.64e+04
# C(month)[T.10] -5.147e+04   3.32e+04     -1.549      0.121   -1.17e+05    1.37e+04
# C(month)[T.11] -5.499e+04   3.45e+04     -1.593      0.111   -1.23e+05    1.27e+04
# C(month)[T.12] -3.509e+04    3.4e+04     -1.033      0.301   -1.02e+05    3.15e+04
# ==============================================================================
# Omnibus:                     6659.305   Durbin-Watson:                   0.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           344790.909
# Skew:                           4.407   Prob(JB):                         0.00
# Kurtosis:                      35.834   Cond. No.                         16.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Washington D.C. Grade

# %%
m = ols('price ~ grade',dc_df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.480
# Model:                            OLS   Adj. R-squared:                  0.479
# Method:                 Least Squares   F-statistic:                     598.7
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):               0.00
# Time:                        22:07:45   Log-Likelihood:            -1.0193e+05
# No. Observations:                7160   AIC:                         2.039e+05
# Df Residuals:                    7148   BIC:                         2.040e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               5.966e+05   1.09e+04     54.870      0.000    5.75e+05    6.18e+05
# grade[T.Average]       -1.592e+05    1.5e+04    -10.618      0.000   -1.89e+05    -1.3e+05
# grade[T.Excellent]      8.854e+05   3.48e+04     25.407      0.000    8.17e+05    9.54e+05
# grade[T.Exceptional-A]  2.366e+06   6.42e+04     36.871      0.000    2.24e+06    2.49e+06
# grade[T.Exceptional-B]  3.849e+06   9.91e+04     38.825      0.000    3.65e+06    4.04e+06
# grade[T.Exceptional-C]  2.503e+06   3.69e+05      6.787      0.000    1.78e+06    3.23e+06
# grade[T.Exceptional-D]  3.687e+06   2.13e+05     17.297      0.000    3.27e+06     4.1e+06
# grade[T.Fair Quality]  -1.491e+05   2.61e+05     -0.571      0.568   -6.61e+05    3.62e+05
# grade[T.Good Quality]   2.242e+05   1.66e+04     13.487      0.000    1.92e+05    2.57e+05
# grade[T.Missing]        -1.02e+05   1.26e+04     -8.067      0.000   -1.27e+05   -7.72e+04
# grade[T.Superior]       1.173e+06   3.76e+04     31.215      0.000     1.1e+06    1.25e+06
# grade[T.Very Good]      5.797e+05   2.34e+04     24.724      0.000    5.34e+05    6.26e+05
# ==============================================================================
# Omnibus:                     6510.201   Durbin-Watson:                   1.110
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           526690.807
# Skew:                           4.057   Prob(JB):                         0.00
# Kurtosis:                      44.226   Cond. No.                         96.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Washington D.C. Condition

# %%
m = ols('price ~ condition',dc_df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     106.6
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):          1.00e-105
# Time:                        22:07:45   Log-Likelihood:                -56887.
# No. Observations:                3884   AIC:                         1.138e+05
# Df Residuals:                    3878   BIC:                         1.138e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               5.066e+05   1.84e+04     27.571      0.000    4.71e+05    5.43e+05
# condition[T.Excellent]  1.635e+06   8.23e+04     19.869      0.000    1.47e+06     1.8e+06
# condition[T.Fair]       3.722e+04   1.36e+05      0.274      0.784    -2.3e+05    3.04e+05
# condition[T.Good]       2.422e+05   2.21e+04     10.984      0.000    1.99e+05    2.85e+05
# condition[T.Poor]       5.514e+05   2.79e+05      1.980      0.048    5288.927     1.1e+06
# condition[T.Very Good]  3.866e+05   2.67e+04     14.465      0.000    3.34e+05    4.39e+05
# ==============================================================================
# Omnibus:                     3135.212   Durbin-Watson:                   0.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           108959.414
# Skew:                           3.610   Prob(JB):                         0.00
# Kurtosis:                      27.923   Cond. No.                         36.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### King County Month

# %%
m = ols('price ~ C(month)',kc_df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.149
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):           0.000287
# Time:                        22:07:45   Log-Likelihood:            -3.0759e+05
# No. Observations:               21613   AIC:                         6.152e+05
# Df Residuals:                   21601   BIC:                         6.153e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       5.259e+05   1.17e+04     44.820      0.000    5.03e+05    5.49e+05
# C(month)[T.2]  -1.802e+04   1.57e+04     -1.150      0.250   -4.87e+04    1.27e+04
# C(month)[T.3]   1.811e+04   1.45e+04      1.251      0.211   -1.03e+04    4.65e+04
# C(month)[T.4]   3.597e+04   1.41e+04      2.556      0.011    8385.424    6.35e+04
# C(month)[T.5]    2.49e+04   1.39e+04      1.790      0.073   -2363.086    5.22e+04
# C(month)[T.6]   3.213e+04   1.41e+04      2.275      0.023    4451.696    5.98e+04
# C(month)[T.7]   1.892e+04   1.41e+04      1.343      0.179   -8701.580    4.65e+04
# C(month)[T.8]   1.057e+04   1.44e+04      0.735      0.462   -1.76e+04    3.88e+04
# C(month)[T.9]   3382.9323   1.46e+04      0.231      0.817   -2.53e+04     3.2e+04
# C(month)[T.10]  1.316e+04   1.45e+04      0.909      0.363   -1.52e+04    4.15e+04
# C(month)[T.11] -3909.8804   1.53e+04     -0.256      0.798   -3.38e+04     2.6e+04
# C(month)[T.12] -1409.0228   1.51e+04     -0.093      0.926   -3.11e+04    2.83e+04
# ==============================================================================
# Omnibus:                    19134.660   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1137713.483
# Skew:                           4.028   Prob(JB):                         0.00
# Kurtosis:                      37.619   Cond. No.                         17.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### King County Grade

# %%
m = ols('price ~ grade',kc_df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.511
# Model:                            OLS   Adj. R-squared:                  0.510
# Method:                 Least Squares   F-statistic:                     2255.
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):               0.00
# Time:                        22:07:45   Log-Likelihood:            -2.9988e+05
# No. Observations:               21613   AIC:                         5.998e+05
# Df Residuals:                   21602   BIC:                         5.999e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               2.144e+05   4.77e+04      4.495      0.000    1.21e+05    3.08e+05
# grade[T.Average]       -8714.3678   1.56e+05     -0.056      0.955   -3.14e+05    2.97e+05
# grade[T.Excellent]      1.882e+05   4.78e+04      3.939      0.000    9.46e+04    2.82e+05
# grade[T.Exceptional-A]  5.591e+05    4.8e+04     11.658      0.000    4.65e+05    6.53e+05
# grade[T.Exceptional-B]  8.574e+05   4.83e+04     17.750      0.000    7.63e+05    9.52e+05
# grade[T.Exceptional-C]  1.282e+06   4.94e+04     25.960      0.000    1.19e+06    1.38e+06
# grade[T.Exceptional-D]  2.168e+06    5.4e+04     40.159      0.000    2.06e+06    2.27e+06
# grade[T.Fair Quality]  -7.238e+04   2.61e+05     -0.277      0.782   -5.84e+05     4.4e+05
# grade[T.Good Quality]   3.414e+04   5.05e+04      0.676      0.499   -6.48e+04    1.33e+05
# grade[T.Superior]       3.285e+05   4.78e+04      6.870      0.000    2.35e+05    4.22e+05
# grade[T.Very Good]      8.754e+04    4.8e+04      1.822      0.068   -6616.533    1.82e+05
# ==============================================================================
# Omnibus:                    17220.696   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1272399.095
# Skew:                           3.303   Prob(JB):                         0.00
# Kurtosis:                      40.004   Cond. No.                         172.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### King County Condition

# %%
m = ols('price ~ condition',kc_df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     37.41
# Date:                Wed, 04 Mar 2020   Prob (F-statistic):           3.12e-31
# Time:                        22:07:45   Log-Likelihood:            -3.0753e+05
# No. Observations:               21613   AIC:                         6.151e+05
# Df Residuals:                   21608   BIC:                         6.151e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               3.273e+05   2.79e+04     11.731      0.000    2.73e+05    3.82e+05
# condition[T.Excellent]  2.851e+05   2.93e+04      9.739      0.000    2.28e+05    3.43e+05
# condition[T.Good]       2.147e+05   2.81e+04      7.650      0.000     1.6e+05     2.7e+05
# condition[T.Poor]       7144.5213   7.24e+04      0.099      0.921   -1.35e+05    1.49e+05
# condition[T.Very Good]  1.939e+05   2.83e+04      6.848      0.000    1.38e+05    2.49e+05
# ==============================================================================
# Omnibus:                    19204.851   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1164858.777
# Skew:                           4.044   Prob(JB):                         0.00
# Kurtosis:                      38.044   Cond. No.                         38.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
