# %% [markdown]
# # SF Crime Statistical Analysis

# %%
# Import necessary modules
from scipy.stats import poisson
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import chi2_contingency

# %%
# Grab dataframe containing police reports
# Create df on Macbook
df = pd.read_csv("/Users/garrettyamane/Desktop/Springboard/capstone_project_1_data/merged.csv")

# Create df on PC
# df = pd.read_csv("/Users/Garrett/Desktop/Springboard/capstone_project_1_data/merged.csv")
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#    Incident Number       Incident Category  \
# 0        100087859  SEX OFFENSES, FORCIBLE
# 1         91139945  SEX OFFENSES, FORCIBLE
# 2         81360718            EMBEZZLEMENT
# 3         81313927          SUSPICIOUS OCC
# 4         81183231  FORGERY/COUNTERFEITING
#
#                     Incident Description Incident Day of Week Incident Date  \
# 0               ANNOY OR MOLEST CHILDREN            Wednesday    2003-01-01
# 1                         SEXUAL BATTERY            Wednesday    2003-01-01
# 2  EMBEZZLEMENT, GRAND THEFT BY EMPLOYEE            Wednesday    2003-01-01
# 3                  SUSPICIOUS OCCURRENCE            Wednesday    2003-01-01
# 4    FORGERY, DRIVERS LICENSE OR ID-CARD            Wednesday    2003-01-01
#
#   Incident Time Police District                              Resolution  \
# 0         00:01        SOUTHERN        COMPLAINANT REFUSES TO PROSECUTE
# 1         00:01         BAYVIEW  DISTRICT ATTORNEY REFUSES TO PROSECUTE
# ...

# %%
# Get Series of Year and the number of crime reports for that year
num_reports_by_year = df['Incident Year'].value_counts().sort_index()

# Drop 2019 from num_reports_by_year since 2019 is not fully updated
num_reports_by_year = num_reports_by_year[0:16]

# Change "Police District" column to lower case for consistency
df["Police District"] = df["Police District"].str.lower()

# %%
# Create figure for number of crime reports and plot
fig, ax = plt.subplots(figsize=(15, 7))
ax.plot(num_reports_by_year.index, num_reports_by_year.values, 'o-b')

# Set title and axis labels
ax.set_title("Total Number of Crime Reports Per Year Since 2003", fontsize=25)
ax.set_xlabel("Year", fontsize=20)
ax.set_ylabel("Number of Crime Reports", fontsize=20)
ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

# Show all years on x-axis
plt.xticks(num_reports_by_year.index)

# Add footnote
plt.annotate('Note: The y-axis does not begin at 0 to accentuate the difference in crime reports over the years', (0,0), (0, -50), xycoords='axes fraction', textcoords='offset points', va='top', fontsize=12)

plt.show()

# %%
print("Variance:", np.var(num_reports_by_year))
num_reports_by_year.describe()
# Out:
# Variance: 57804070.484375
# count        16.000000
# mean     145191.875000
# std        7852.240138
# min      132697.000000
# 25%      139358.250000
# 50%      145167.000000
# 75%      151363.750000
# max      156526.000000
# Name: Incident Year, dtype: float64

# %% [markdown]
# # Crime Report Rate: Is there a statistical significance between the average number of crimes per year between different police districts?

# %% [markdown]
# From the above graph, it is clear that some years were better/worse than others. 2011 saw the lowest crime report rate in the past 15 years, whereas in 2015 the crime report rate reached its peak. Initially, it would seem interesting to model this rate as a Poisson distribution. However, in order to measure the number of arrivals (crimes) per unit of time, a Poisson random variable would need to meet a few assumtions: <br>
#
# -*Independence*: Events must be independent (one crime cannot impact the probability of another crime)<br>
# -*Homogeneity*: The mean number of crimes is assumed to be the same for all neighborhoods.<br>
# -*Time period*: must be fixed<br>
#
# There are a few issues that I must address. San Francisco contains many police districts, some of which are culturally, demographically, or financially different. Mean crime report rate in one police district will most likely not be the same for other districts. Crimes from adjacent police districts may have an influence on each other as well. Lastly, Poisson Regression models require that the mean and variance of the dependent variable to be equal. This assumption can lead to overdispersion with my data points for crimes per year, since the variance and mean are quite different.
#
# Because of these issues, I will examine crime report rate per year for individual police districts. By isolating police districts and exploring their individual crime report rates, I can highlight the differences of means between police district crime report rates and hopefully distinguish specific districts where the San Francisco Police Department can focus their resources on.

# %%
district_counts = pd.DataFrame(df['Police District'].value_counts())
district_counts = district_counts.reset_index()
district_counts.columns = ['Police District', 'Number of Reports']
district_counts
# Out:
#    Police District  Number of Reports
# 0         southern             422414
# 1          mission             326998
# 2         northern             298486
# 3          central             259736
# 4          bayview             236703
# 5       tenderloin             213807
# 6        ingleside             207715
# 7          taraval             180113
# 8             park             134481
# 9         richmond             128340
# 10       out of sf               6504

# %%
def graph_neighborhood(df, district, mean_dict, yearly_dict):
    """Graphs number of crimes for specific district from 2003-2018"""
    
    # Initialize police district dataframe
    df_pd = df[df["Police District"] == district]
    
    # Get number of crimes per year and drop 2019
    num_reports_by_year = df_pd['Incident Year'].value_counts().sort_index()
    num_reports_by_year = num_reports_by_year[0:16]
    
    # Create figure for number of crime reports and plot
    fig, ax = plt.subplots(figsize=(15, 7))
    ax.plot(num_reports_by_year.index, num_reports_by_year.values, 'o-b')

    # Set title and axis labels
    ax.set_title(district + " Police District: Crime Reports Per Year Since 2003", fontsize=25)
    ax.set_xlabel("Year", fontsize=20)
    ax.set_ylabel("Number of Crime Reports", fontsize=20)
    ax.tick_params(axis = 'both', which = 'major', labelsize = 15)

    # Show all years on x-axis
    plt.xticks(num_reports_by_year.index)
    
    # Start y-axis at 0 for consistency
    ax.set_ylim(bottom=0)
    
    # Add mean line and update dictionaries
    avg = num_reports_by_year.mean()
    ax.axhline(avg, ls='--', label="Mean")
    mean_dict[pd] = avg
    yearly_dict[pd] = list(num_reports_by_year)
    
    # Add footnote to notify that police district boundaries changed in 2015
    plt.annotate('Note: Police District boundaries changed in 2015', (0,0), (0, -50), xycoords='axes fraction', textcoords='offset points', va='top', fontsize=12)
    
    ax.legend(loc="lower right", prop={'size': 15})

    plt.show()

# %%
# Plot individual police districts
districts = list(district_counts["Police District"])
districts.remove("out of sf")
pd_mean_dict = {}
pd_yearly_dict = {}

for d in districts:
    graph_neighborhood(df, d, pd_mean_dict, pd_yearly_dict)

# %% [markdown]
# An important thing to take note of is the change in district boundaries in 2015. To maintain consistency between comparisons, I will look at the mean crime report rates for each district from 2015 onwards. I want to make sure that any reports for a district are not cross-referenced with different data sets. 2015-2018 contains a sample of 4 separate data points to be used. Each data point is the number of *crime reports* for a year, given that some crimes may go unreported. By using this sample for each district, I can explore if the difference of *population means* for *all* crimes (reported and unreported) per year between two districts are the same, or if there is a statistical significance between the means.
#
# Because my sample size is small (<30), I will be using a t-test to test the significance between the two means. Under the assumption that each district's crime reports are independent and that the two populations have the same variance, I will compare the difference of means between specific police districts by testing the following hypotheses:
#
# ***H<sub>0</sub>***: The true mean crime rate between the two police districts are the same <br>
# ***H<sub>1</sub>***: The true mean crime rate between the two police districts are not the same<br>
# For each, I assume an $\alpha$ level of 0.05

# %%
# Create dataframe with 2015-2018 crime reports
df_2015_2018 = df.copy()
df_2015_2018["Incident Month"] = pd.to_datetime(df_2015_2018["Incident Date"]).dt.month
df_2015_2018 = df_2015_2018[df_2015_2018["Incident Year"] >= 2015]
df_2015_2018 = df_2015_2018[df_2015_2018["Incident Year"] < 2019]

# Get police districts in order of most to least number of crimes, and delete last index ("out of sf" district not applicable)
ordered_districts = list(df_2015_2018['Police District'].value_counts().index)
del ordered_districts[-1]

# %%
def get_means_variances_totals(df, districts):
    """Get average number of crimes per year and variances of each police district"""
    means = []
    variances = []
    totals = []
    for d in districts:
        # Initialize police district dataframe and update 'means' and 'variance' lists
        df_pd = df[df["Police District"] == d]
        means.append(np.mean(df_pd['Incident Year'].value_counts().values))
        variances.append(np.var(df_pd['Incident Year'].value_counts().values, ddof=1))
        totals.append(sum(df_pd['Incident Year'].value_counts().values))
    return means, variances, totals

# %%
means, variances, totals = get_means_variances_totals(df_2015_2018, ordered_districts)
df_districts = pd.DataFrame({"Mean Per Year":means, "Variance":variances, "Total Reports":totals}, index=ordered_districts)
df_districts.index.name="Police District"
df_districts
# Out:
#                  Mean Per Year      Variance  Total Reports
# Police District
# southern              26848.50  1.949013e+07         107394
# mission               20342.50  2.423115e+06          81370
# northern              20130.25  5.389582e+05          80521
# central               20011.50  1.041427e+07          80046
# bayview               13818.50  1.223255e+06          55274
# ingleside             11874.50  1.143297e+06          47498
# taraval               11501.00  5.272353e+05          46004
# tenderloin            11223.75  8.588913e+06          44895
# richmond               8993.25  1.796556e+05          35973
# park                   8479.75  7.493216e+05          33919

# %% [markdown]
# ## Southern vs. Park
# The first two police districts of interest to me are the districts that had the most and least crimes per year: "southern" and "park".

# %%
# Compute the test statistic
test_stat = df_districts.loc["southern", "Mean Per Year"] - df_districts.loc["park", "Mean Per Year"]
print("Difference of means for Southern and Park:", test_stat)
# Out:
# Difference of means for Southern and Park: 18368.75

# %% [markdown]
# *Process referenced from: http://onlinestatbook.com/mobile/tests_of_means/difference_means.html*<br>
# Next, I will calculate the standard error of the test statistic (difference of means). Since I am assuming that the two populations have the same variance, I will take the average of the variances of Southern and Park to calculate the mean squared error (MSE), and use this estimate in my calculatio of the standard error.<br>
#
# Using my standard error, I can compute the t-statistic. This will give me the p-value I need to decide whether or not to reject the null hypothesis that there is no statistical difference between the means of "Southern" and "Park" police districts.

# %%
sample_size = 4

# Calculate MSE
mse = (df_districts.loc["southern", "Variance"] + df_districts.loc["park", "Variance"]) / 2

# Calculate standard error of test statistic
standard_err = np.sqrt(2*mse/sample_size)

# Compute t-statistic
t_stat = test_stat / standard_err

# Degrees of freedom
dof = 2*sample_size - 2

# Compute p-value
p_val = 1 - stats.t.cdf(t_stat,df=dof)

print("p-value:", p_val)
# Out:
# p-value: 9.075809058534112e-05

# %% [markdown]
# Since the p-value is less than 0.05, I can confidently reject my null hypothesis that the true means of "Southern" and "Park" are the same. This statistical significance can help me look deeper into the differences beween each of these police districts. "Southern" police district is clearly more dangerous since the crime rate per year is higher compared to the lowest district, and it would be interesting to look into why this may be.<br>
#
# Another comparison that I would like to make are between the two middle police districts: "Bayview" and "Ingleside". The crime report rates of these two police districts are much closer than "Southern" and "Park", so I would like to explore if there is a statistical significance between these two districts as well. I will follow the same process as above to compute the p-value under the null hypothesis that the means of "Bayview" and "Ingleside" are the same.

# %% [markdown]
# ## Bayview vs. Ingleside

# %%
# Compute the test statistic
test_stat = df_districts.loc["bayview", "Mean Per Year"] - df_districts.loc["ingleside", "Mean Per Year"]
print("Difference of means for Bayview and Ingleside:", test_stat)
# Out:
# Difference of means for Bayview and Ingleside: 1944.0

# %%
# Calculate MSE
mse = (df_districts.loc["bayview", "Variance"] + df_districts.loc["ingleside", "Variance"]) / 2

# Calculate standard error of test statistic
standard_err = np.sqrt(2*mse/sample_size)

# Compute t-statistic
t_stat = test_stat / standard_err

# Degrees of freedom
dof = 2*sample_size - 2

# Compute p-value
p_val = 1 - stats.t.cdf(t_stat,df=dof)

print("p-value:", p_val)
# Out:
# p-value: 0.022419406421560928

# %% [markdown]
# Since the p-value is less than 0.05, I can confidently reject my null hypothesis that the true means of "Bayview" and "Ingleside" are the same. Although the means are much closer together, the crime rates between these two police districts are still significant.<br>
#
# One more test I would like to run is between the two police districts that the difference in means is the smallest: "Taraval" and "Tenderloin".

# %% [markdown]
# ## Taraval vs. Tenderloin

# %%
# Compute the test statistic
test_stat = df_districts.loc["taraval", "Mean Per Year"] - df_districts.loc["tenderloin", "Mean Per Year"]
print("Difference of means for Bayview and Ingleside:", test_stat)
# Out:
# Difference of means for Bayview and Ingleside: 277.25

# %%
# Calculate MSE
mse = (df_districts.loc["taraval", "Variance"] + df_districts.loc["tenderloin", "Variance"]) / 2

# Calculate standard error of test statistic
standard_err = np.sqrt(2*mse/sample_size)

# Compute t-statistic
t_stat = test_stat / standard_err

# Degrees of freedom
dof = 2*sample_size - 2

# Compute p-value
p_val = 1 - stats.t.cdf(t_stat,df=dof)

print("p-value:", p_val)
# Out:
# p-value: 0.4301678325400238

# %% [markdown]
# Here, the p-value is 0.43, which is much higher than 0.05. I cannot reject the null hypothesis in this case, which means that I *cannot* reject the null hypothesis that the true mean crime rate of "Taraval" and "Tenderloin" are the same. These two districts could share similarities that make them have simlar crime rates, which would also be interesting to look further into.

# %% [markdown]
# # Chi-square test of independence to identify important features associated with the type of crime committed
#
# In my data storytelling, I created a separated crime reports from 2003-2017 and 2018-2019. The values that the crime features could take on were slightly different due to the update that the San Francisco Crime Data Warehouse went through at the start of 2018, which would skew the potential relationships between different features. For the following tests, I will be focusing on crimes committed from 2018 onward to focus on the updated data in the Crime Data Warehouse.<br>
#
# My target feature that I would like to compare to other features is "Incident Category." By looking at the association between the type of crime that is committed and other independent variables, I can identify important features to use for my machine learning models later on. I will test the following hypotheses:<br>
#
# ***H<sub>0</sub>***: There is no association between "Incident Category" and the comparison variable<br>
# ***H<sub>1</sub>***: There is evidence to suggest that there is an association between "Incident Category" and the comparison variable<br>
# For each test, I assume an $\alpha$ level of 0.05

# %%
# Create dataframe with reports from 2018-2019
df_2018_2019 = df.copy()
df_2018_2019  = df_2018_2019[df_2018_2019["Incident Year"] >= 2018]
df_2018_2019["Incident Month"] = pd.to_datetime(df_2018_2019["Incident Date"]).dt.month
df_2018_2019["Incident Hour"] = df_2018_2019["Incident Time"].str.split(':').str[0]

# %%
list(df_2018_2019.columns)
# Out:
# ['Incident Number',
#  'Incident Category',
#  'Incident Description',
#  'Incident Day of Week',
#  'Incident Date',
#  'Incident Time',
#  'Police District',
#  'Resolution',
#  'Intersection',
#  'Longitude',
#  'Latitude',
#  'point',
#  'Row ID',
#  'Incident Year',
#  'Analysis Neighborhood',
#  'Incident Month',
#  'Incident Hour']

# %% [markdown]
# Crime features like "point" and "Intersetction" have thousands of categories. This would make running a chi-square test on these variables much more difficult, so I will focus on the variables that have a more reasonable number of categories. Some code will be referenced from http://www.insightsbot.com/blog/2AeuRL/chi-square-feature-selection-in-python to help build some of the functions of the chi-square test.
#
# The crime features that I plan on running a chi-square test with are "Incident Hour", "Incident Day of Week", "Incident Month", "Police District", and "Resolution". However, there are a couple of transformations that I want to make to "Incident Hour" and "Incident Month." Because these contain interval data (1, 2, 3...), I will transform these two columns to more usable categorical data. Hours can be split into "morning", "afternoon", "evening", and "night" and months can be split into seasons.

# %%
def label_hour(row):
    """Return either monring, afternoon, evening, or night depending on the hour of the day"""
    hour = int(row["Incident Hour"])
    if hour >= 5 and hour < 12 :
        return 'morning'
    elif hour >= 12 and hour < 17:
        return 'afternoon'
    elif hour >= 17 and hour < 21:
        return 'evening'
    return 'night'


def label_season(row):
    """Return either spring, summer, fall, or winter depending on the month of the year"""
    month = row["Incident Month"]
    spring = [3, 4, 5]
    summer = [6, 7, 8]
    fall = [9, 10, 11]
    winter = [12, 1, 2]
    
    if month in spring:
        return 'spring'
    elif month in summer:
        return 'summer'
    elif month in fall:
        return 'fall'
    return 'winter'

# %%
# Add new columns for hour and seasons
df_2018_2019['Time Category'] = df_2018_2019.apply(lambda row: label_hour(row), axis=1)
df_2018_2019['Season'] = df_2018_2019.apply(lambda row: label_season(row), axis=1)
df_2018_2019[["Incident Hour", "Incident Month","Time Category", "Season"]].tail()
# Out:
#         Incident Hour  Incident Month Time Category  Season
# 2415293            12               8     afternoon  summer
# 2415294            00               8         night  summer
# 2415295            00               8         night  summer
# 2415296            12               8     afternoon  summer
# 2415297            12               8     afternoon  summer

# %%
# Create list of comparison variabes
comparison_cols = ["Time Category", "Incident Day of Week", "Season", "Police District", "Resolution"]

# Code referenced from ttp://www.insightsbot.com/blog/2AeuRL/chi-square-feature-selection-in-python
class ChiSquare:
    def __init__(self, dataframe):
        """Chi-square class constructor"""
        self.df = dataframe
        self.p = None #P-Value
        self.chi2 = None #Chi Test Statistic
        self.dof = None
        
        self.dfTabular = None
        self.dfExpected = None
        
    def _print_chisquare_result(self, colX, alpha):
        """Prints whether or not the comparison variable is important or not by computing p-value and comparing it to alpha level"""
        result = ""
        if self.p<alpha:
            result="{0} is IMPORTANT for Prediction".format(colX)
        else:
            result="{0} is NOT an important predictor. (Discard {0} from model)".format(colX)
        print(result)
    
    def TestIndependence(self,colX,colY, alpha=0.05):
        """Tests two categorical variables for independence and prints result"""
        X = self.df[colX].astype(str)
        Y = self.df[colY].astype(str)
        
        self.dfObserved = pd.crosstab(Y,X) 
        chi2, p, dof, expected = stats.chi2_contingency(self.dfObserved.values)
        self.p = p
        self.chi2 = chi2
        self.dof = dof 
        
        self.dfExpected = pd.DataFrame(expected, columns=self.dfObserved.columns, index = self.dfObserved.index)
        
        self._print_chisquare_result(colX,alpha)

# %%
# Run chi-square independence test against comparison columns
chi_square = ChiSquare(df_2018_2019)
for var in comparison_cols:
    chi_square.TestIndependence(colX=var,colY="Incident Category" )
# Out:
# Time Category is IMPORTANT for Prediction
# Incident Day of Week is IMPORTANT for Prediction
# Season is IMPORTANT for Prediction
# Police District is IMPORTANT for Prediction
# Resolution is IMPORTANT for Prediction

# %% [markdown]
# From the resulting chi-square test run on "Time Category", "Incident Day of Week", "Season", "Police District", and "Resulution", each had a resulting p-value of less than my $\alpha$ level of 0.05. This means that I can reject my null hypothesis and accept that there is evidence to suggest that there is an association between each of these crime features with "Incident Category" (the type of crime that is committed).<br>
#
# To test that my chi-square test works with irrelevant information, I will test it with "Row ID". "Row ID" is just a unique identifier for the dataset, which has no relationship to the type of crime.

# %%
chi_square.TestIndependence(colX="Row ID",colY="Incident Category")
# Out:
# Row ID is NOT an important predictor. (Discard Row ID from model)
